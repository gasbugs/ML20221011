# %% [markdown]
# # 판다스 시각화
#
# 데이터를 그리기 위해 필요한 라이브러리들을 임포트한다.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## 기본 그리기
# 시리즈를 사용해서 데이터를 시각해보자.

# %%
# 넘파이로 정규화된 데이터 100개를 구성하고 cumsum 사용해 누적합을 계산한다.
se0 = pd.Series(np.random.randn(100).cumsum())
se0.plot() # 메모리에 그림을 그려요. 
# plt.show()
# Out:
# <AxesSubplot:>

# %%
df = pd.DataFrame(np.random.randn(100, 5).cumsum(0),
                  columns= ['arr1', 'arr2', 'arr3', 'arr4', 'arr5'] )
df.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 막대 그래프 그리기

# %%
se0.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# 옆으로 바 차트 그리기

# %%
se0.plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='bar', stacked=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 히스토그램
# 값의 빈도를 분리해서 출력

# %%
se0.hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
df.hist(bins=50)
# Out:
# array([[<AxesSubplot:title={'center':'arr1'}>,
#         <AxesSubplot:title={'center':'arr2'}>],
#        [<AxesSubplot:title={'center':'arr3'}>,
#         <AxesSubplot:title={'center':'arr4'}>],
#        [<AxesSubplot:title={'center':'arr5'}>, <AxesSubplot:>]],
#       dtype=object)

# %% [markdown]
# ## 커널 밀도 추정 그래프

# %%
se0.plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df.plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# ## 그래프 중첩 그리기

# %%
se0.hist(bins=100,  density=True)
se0.plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# # iris 데이터를 활용한 산포도 그리기

# %%
from sklearn import datasets

iris = datasets.load_iris()
irisdt = pd.DataFrame(iris['data'], columns=iris['feature_names'])
irisdt
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
plt.scatter(irisdt['sepal length (cm)'], irisdt['sepal width (cm)'], c=iris.target)

# %% [markdown]
# ## 연습문제
# for 문을 사용해 iris 데이터의 12개의 그림을 모두 그려보자.

# %%
for f0 in iris['feature_names']: # irisdt에서는 columns 이름을 뽑아야 함
    for f1 in iris['feature_names']:
        if f0 == f1:
            continue
        plt.scatter(irisdt[f0], irisdt[f1], c=iris.target)
        plt.title(f"{f0} vs {f1}")
        plt.show()

# %% [markdown]
# 피봇 테이블 만들기

# %%
csv_data = '''\
구분,죄종,발생검거,건수
중부,살인,발생,3
중부,살인,검거,2
중부,강도,발생,8
중부,강도,검거,8
중부,강간,발생,143
중부,강간,검거,105
'''

with open('중부 지역 강력 사건 발생 검거 통계.csv', 'w', encoding='UTF-8') as f:
    f.write(csv_data)

df = pd.read_csv('중부 지역 강력 사건 발생 검거 통계.csv')
pd.pivot_table(df, index=['죄종', '발생검거'], aggfunc=np.sum)
# Out:
#           건수
# 죄종 발생검거
# 강간 검거    105
#    발생    143
# 강도 검거      8
#    발생      8
# 살인 검거      2
#    발생      3

# %% [markdown]
# # 타이타닉 생존자 분석 연습 문제
# 피봇 테이블을 사용해 데이터를 분석해봅시다.
# 1. 가장 많이 살아 남은 성별은 남녀 중 어느 쪽인가요?
# 2. 가장 많이 살아 남은 Class는 어디 인가요? (예: 1,2,3)
# 3. 가장 많이 살아 남은 연령대는 어느 연령대 인가요? (예: 30대)
# 4. 두 번째로 가장 많이 살아 남은 연령대는 어느 연령 대 인가요? (예: 30대)

# %%
titanic_df = pd.read_csv('titanic_train.csv')
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# 1
titanic_df['Survived'].groupby(titanic_df['Sex']).mean()
# Out:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %%
titanic_df.pivot_table(index=['Sex'])['Survived']
# Out:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %%
# 2
titanic_df.pivot_table(index=['Pclass'], aggfunc=np.sum)['Survived']
# Out:
# Pclass
# 1    136
# 2     87
# 3    119
# Name: Survived, dtype: int64

# %%
titanic_df['Survived'].groupby(titanic_df['Pclass']).sum()
# Out:
# Pclass
# 1    136
# 2     87
# 3    119
# Name: Survived, dtype: int64

# %%
# 3, 4
ages = []
for index, row in titanic_df.iterrows():
    ages.append((row['Age']//10) * 10)

titanic_df['ages'] = ages

titanic_df['Survived'].groupby(titanic_df['ages']).sum().sort_values(ascending=False)
# Out:
# ages
# 20.0    77
# 30.0    73
# 10.0    41
# 0.0     38
# 40.0    34
# 50.0    20
# 60.0     6
# 80.0     1
# 70.0     0
# Name: Survived, dtype: int64

# %%
titanic_df['Survived'].groupby(titanic_df['ages']).sum().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='ages'>

# %%
def age_to_ages(df):
    return (df['Age']//10) * 10

titanic_df.apply(age_to_ages, axis=1)
# Out:
# 0      20.0
# 1      30.0
# 2      20.0
# 3      30.0
# 4      30.0
#        ...
# 886    20.0
# 887    10.0
# 888     NaN
# 889    20.0
# 890    30.0
# Length: 891, dtype: float64

# %% [markdown]
# # 머신러닝 맛보기

# %%
from sklearn import datasets

iris = datasets.load_iris()
irisdt = pd.DataFrame(iris['data'], columns=iris['feature_names'])
irisdt
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
from sklearn import neighbors

x = iris['data']
y = iris['target']

knn = neighbors.KNeighborsClassifier() # knn 알고리즘은 분류를 하는 기능을 가진다.
knn.fit(x, y) # 특징과 결과를 가지고 훈련 시킨다.
# Out:
# KNeighborsClassifier()

# %%
# 임의의 x를 넣어서 답을 요구하면 모델은 그 답을 준다.
knn.predict([[5.1, 3.5, 1.4, 0.2], [0,0,0,0]])
# Out:
# array([0, 0])

# %%
knn.score(x, y) # 모델로 prediction을 수행하고 y 채점한 결과
# Out:
# 0.9666666666666667

# %% [markdown]
# # Seaborn을 활용한 데이터 시각화

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style='darkgrid')

# %%
tips_df = sns.load_dataset("tips")
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ## 관계형 데이터 그리기

# %%
sns.relplot(data=tips_df, x="total_bill", y="tip")

# %%
sns.relplot(data=tips_df, x="total_bill", y="tip", hue='smoker') # 색상으로 세 번째 특징인 흡연 여부

# %%
sns.relplot(data=tips_df, x="total_bill", y="tip", hue='smoker', style='time') # 모양으로 네 번째 특징인 식사 인원

# %%
sns.relplot(data=tips_df, x="total_bill", y="tip", hue="size") # 색상으로 숫자를 표현

# %%
sns.relplot(data=tips_df, x="total_bill", y="tip", size="size") # 크기로 숫자를 표현

# %%
_dict = dict(time=np.arange(500), value=np.random.randn(500).cumsum())
timeseries_df = pd.DataFrame(_dict)
timeseries_df
# Out:
#      time      value
# 0       0   1.361698
# 1       1   2.226999
# 2       2   2.873606
# 3       3   4.387910
# 4       4   4.677645
# ..    ...        ...
# 495   495  50.269926
# 496   496  50.762702
# 497   497  50.275031
# 498   498  51.449641
# 499   499  52.253549
#
# [500 rows x 2 columns]

# %%
# 시간에 따른 값이 어떻게 변화되는 라인 차트로 그림
sns.relplot(data=timeseries_df,x='time', y='value', kind='line')

# %%
# 타임 인덱스가 겹치는 데이터
fmri = sns.load_dataset("fmri")
fmri
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
sns.relplot(data=fmri, x='timepoint', y='signal')

# %%
sns.relplot(data=fmri, x='timepoint', y='signal', kind='line')

# %%
sns.relplot(data=fmri, x='timepoint', y='signal', kind='line', ci="sd")

# %%
sns.relplot(data=fmri, x='timepoint', y='signal', kind='line', hue="region", style='event')

# %% [markdown]
# ## 범주형 데이터 그리기

# %%
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.catplot(data=tips_df, x='day', y='total_bill')

# %%
sns.catplot(data=tips_df, x='day', y='total_bill', kind='swarm')

# %%
sns.catplot(data=tips_df, x='day', y='total_bill', hue="sex", kind='swarm')

# %%
sns.swarmplot(data=tips_df, x='day', y='total_bill', hue="sex", size=4, dodge=True)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.catplot(data=tips_df, x='day', y='total_bill', hue="sex",
            kind='violin', palette='pastel', split=True)

# %%
sns.catplot(data=tips_df, kind='bar', x='day', y='total_bill', hue='sex', palette='pastel')

# %%
sns.catplot(data=tips_df, kind='bar', x='day', y='total_bill', hue='smoker', palette='pastel')

# %%
sns.catplot(data=tips_df, x='day', kind='count') # 위 아래 그려짐
#sns.countplot(data=tips_df, x='day')

# %%
sns.catplot(data=tips_df, y='size', kind='count') # 옆으로 그려짐
